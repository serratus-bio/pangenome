# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://interproscan-docs.readthedocs.io/en/latest/HowToDownload.html
#
# https://ictv.global/vmr

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# submitjob -h

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# https://pypi.org/project/pygenomeviz/

# %% [markdown]
# ![image.png](attachment:image.png)
# https://plantsandpython.github.io/PlantsAndPython/P_9_COMPARATIVE_GENOMICS/0_Lessons/9.0_Comp_Genomics.html

# %% [markdown]
# ![image.png](attachment:image.png)
# a map to good visualization tools
#
# https://cmdcolin.github.io/awesome-genome-visualization/?latest=true
#
# ![image-2.png](attachment:image-2.png)
# https://github.com/nspies/genomeview
#
# ![image-3.png](attachment:image-3.png)
# https://github.com/codeatcg/VRPG
#
# ![image-4.png](attachment:image-4.png)
# https://github.com/phageghost/python-genome-browser/blob/master/pygbrowse_demonstration.ipynb
#
# ![image-5.png](attachment:image-5.png)
# https://github.com/Sanrrone/multiGenomicContext
#
# ![image-6.png](attachment:image-6.png)
# https://github.com/mdbaron42/pyBoxshade
