# %% [markdown]
# ### logging keywords
#
# asctime: 可读的时间格式，如'2003-07-08 16:49:45,896'（时间戳通常按照%(asctime)s指定的格式呈现）。<br>
# name: 日志器的名称。<br>
# levelname: 文本形式的日志级别（'DEBUG', 'INFO', 'WARNING', 'ERROR', 'CRITICAL'）。<br>
# message: 日志消息本身，通过msg % args计算得到。<br>
#
#
# 截至我最后更新的时间（2023年4月），这里是一些其他可能用到的关键词：<br>
# filename: 不包含目录的文件名，从哪个文件生成了日志记录。<br>
# pathname: 完整的调用源文件路径。<br>
# funcName: 日志记录所在的函数名。<br>
# lineno: 日志记录的行号。<br>
# thread: 线程ID。<br>
# threadName: 线程名。<br>
# process: 进程ID。<br>
# message: 用户输出的消息。<br>

# %% [markdown]
# CALL apoc.periodic.iterate(
#   "UNWIND {yourList} AS list RETURN list",
#   "YOUR MERGE/CREATE QUERY HERE USING list",
#   {batchSize:100, parallel:false, params:{yourList: $yourList}}
# )

# %% [markdown]
# CALL apoc.periodic.iterate(
# '
# match (s)-[r]->(e)
# ','
# with s,e,type(r) as typ, tail(collect(r)) as coll
# foreach(x in coll | delete x)
# '
# {batchSize:10000, parallel:True}) YIELD batches, total
# RETURN batches, total

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# hhr's consensus row

# %% [markdown]
# ![image.png](attachment:image.png)
# annotation tracks

# %% [markdown]
# Neff:
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# ref:
# https://pure.mpg.de/rest/items/item_3316993/component/file_3373758/content

# %% [markdown]
# ![image.png](attachment:image.png)
# https://github.com/soedinglab/hh-suite/wiki#how-is-the-msa-diversity-neff-calculated

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# April 18

# %% [markdown]
# TODO: log basic info of 'parsing xxx'
#
# no hit (ERROR - error:'begin'): 825, maybe threshold for valid ORF (300 aa) is too high?
# No objects to concatenate: 52, waht's this?
# Failed to write data to connection IPv4Address: 15
# no valid hit: 681, threshold (prob>0.8)
#
# 8210 fasta
# 7385 ori.pkl
# 6651 pcs.pkl
# * don't use ls to calculate file number, not so precise

# %% [markdown]
# April 19

# %% [markdown]
# time to process 7384 (and commit 6701): 10h

# %% [markdown]
# Error due to repeated commit: replace it with merge-like, tolerant functions (maybe later, get rid of neomodel as a whole).
# ![image.png](attachment:image.png)

# %% [markdown]
# 1234 "same hit across groups" but only 16 (9) merged: check the interval_ratio's treshold.
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# 681 "BREAK! no valid hit": check their hit count and max-prob
# TODO: maybe still update their fasta?

# %% [markdown]
# TODO: single syteny plot from neo4j (simple rainbow color, for quick visualization)
# input: only the fasta name

# %% [markdown]
# TODO: on-the-fly calculation of 1) pairwise Hit similarity; 2) Hit Family Connection
# (in order to avoid the error-prone post-updating)

# %%
TODO: consider information to commit to Pfam-HHblits HitFamily
(Least: pairwise hhalign similarity)

# %% [markdown]
# Realm
# member_num:    7 | null_count:931
# Subrealm
# member_num:    1 | null_count:16385
# Kingdom
# member_num:   11 | null_count:1028
# Subkingdom
# member_num:    1 | null_count:16385
# Phylum
# member_num:   18 | null_count:1067
# Subphylum
# member_num:    3 | null_count:13551
# Class
# member_num:   41 | null_count:971
# Subclass
# member_num:    1 | null_count:16385
# Order
# member_num:   73 | null_count:4989
# Suborder
# member_num:    9 | null_count:16248
# Family
# member_num:  264 | null_count:2296
# Subfamily
# member_num:  183 | null_count:11853
# Genus
# member_num: 2816 | null_count:13
# Subgenus
# member_num:   85 | null_count:16233
# Species
# member_num:11097 | null_count:0

# %% [markdown]
# ![image.png](attachment:image.png)
#
# length distribution of concatenated virus-protein-seq ('-' included)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# length distribution of concatenated virus-protein-seq ('-' not included)
