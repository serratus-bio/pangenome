# %% [markdown]
# ## neomodel
#
# define your graph database model in a Pythonic way and then access and edit your data without needing to write Cypher queries.

# %% [markdown]
# Mixin
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Wrtite
# create_or_update / get_or_create
# ![image.png](attachment:image.png)

# %% [markdown]
# Query
#
# https://neomodel.readthedocs.io/en/latest/queries.html
#
# get / filter
#
# ![image.png](attachment:image.png)
#
# Q object
#
# ![image-2.png](attachment:image-2.png)
#
# has relationship
#
# ![image-3.png](attachment:image-3.png)
#
# order
#
# ![image-4.png](attachment:image-4.png)
#
# cypher query:
#
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# Utility
# ![image.png](attachment:image.png)

# %% [markdown]
# Output as Pandas:
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# FuncDomainSet.nodes.get(**dict(
#             name=name,
#             annotation=annot,
#             accession=s['accession']))
#
# from neomodel import clear_neo4j_database
# clear_neo4j_database(db,clear_constraints=True,clear_indexes=True)
#
# config.DATABASE_URL = 'bolt://neo4j:WBrtpKCUW28e@44.206.130.87:7687'
# results, meta = db.cypher_query("RETURN 'Hello World' as message")

# %% [markdown]
# query's parameter. not so useful with python's str funcs
#
# ![image.png](attachment:image.png)
