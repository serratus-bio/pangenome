# %% [markdown]
# ![image.png](attachment:image.png)
#
# MATCH (n:FuncDomainSet )-[:HasMember]->(f:FuncDomain)<-[y:HasReg]-(:Genome {name:'EBOV||AF086833'})
# RETURN n,f
#
# WARNING: consecutive same domain turns out to be one domain:
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
#
#
#
# #TODO MATCH issue:
# the regid need to be 'fixed'
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
#
# ####################################################
#
# #TODO one genome with 2 domain of the same name!

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 3d layout

# %% [markdown]
# ![-+](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
