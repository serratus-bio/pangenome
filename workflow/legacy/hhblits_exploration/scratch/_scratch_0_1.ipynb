# %% [markdown]
# post processing of hhblits

# %%
import pickle as pkl
from typing import List,Dict,Tuple,Union
from pathlib import Path
import pandas as pd
search_result:List[Tuple[Path,List[Tuple[Path,List[str]]]]]=pkl.load(open('blit_out.pkl','rb'))

# %%
from Bio import SeqIO
from Bio.SeqRecord import SeqRecord
from Bio.Seq import Seq

# %%
def proindice_to_genindice(genome:Union[str,Seq],prob:int,proe:int,transannot:str)->Tuple[int,int]:
    frame,direction=transannot
    frame=int(frame)
    b_,e_=frame+prob*3,frame+proe*3
    if direction=='s':
        return b_,e_
    else:
        return len(genome)-e_, len(genome)-b_

def genindice_to_proindice(genome:Union[str,Seq],genb:int,gene:int,transannot:str)->Tuple[int,int]:
    frame,direction=transannot
    frame=int(frame)
    
    if direction=='s':
        b_,e_=(genb-frame)//3,(gene-frame)//3
        return b_,e_
    else:
        return (len(genome)-frame-gene)//3,(len(genome)-frame-genb)//3
        

def genome_annot_indice(genome:Union[str,Seq],genb:int,gene:int,transannot:str)->Tuple[int,int]:
    'return: genseq segments '
    frame,direction=transannot
    # frame=int(frame)
    o=genome[genb:gene]
    o=o if direction=='s' else o[::-1]
    return o

# %%
from dna_features_viewer import GraphicFeature, GraphicRecord
import matplotlib.pyplot as plt
import matplotlib.colors as clr
import matplotlib.patches as patches

# %%
from collections import namedtuple
from matplotlib import colormaps
import matplotlib.colors as mcolors

Hit=namedtuple('Hit',('domain_accession','domain_annotation',
    'prob','eval','pval','score','ss','begin','end','hmmbegin','hmmend','hmmlength'))
SegMeta=namedtuple('SegMeta',("transannot",'seg_b','seg_e'))

def split_hit_line(hit_line:str)->List[str]:
    i=hit_line
    assert len(i)>94
    return [i[:4],i[4:34],i[34:40],i[40:48],i[48:56],i[56:63],
            i[63:69],i[69:74],i[74:85],i[85:94],i[94:]]

def parse_splited_hit_line(hit:List[str])->Hit:
    domain_accession,*_=hit[1].split(';')
    domain_accession=domain_accession.split('.')[0].strip()
    if len(_)>0:
        domain_annotation=_[0].strip()
    else:
        domain_annotation=domain_accession
        
    prob=float(hit[2].strip())
    e=float(hit[3].strip())
    p=float(hit[4].strip())
    score=float(hit[5].strip())
    ss=float(hit[6].strip())
    begin,end=[int(i.strip())-1 for i in hit[8].split('-')]
    hmmbegin,hmmend=[int(i.strip())-1 for i in hit[9].split('-')]
    hmmlength=int(hit[10].strip().strip('(').strip(')'))
    h=Hit(domain_accession=domain_accession,domain_annotation=domain_annotation,
        prob=prob,eval=e,pval=p,score=score,ss=ss,
        begin=begin,end=end,hmmbegin=hmmbegin,hmmend=hmmend,hmmlength=hmmlength)
    return h

# %%
from itertools import accumulate
def get_color(genome_position:float,prob:float):
    ''' domain colors based on relative position'''
    cm=mcolors.LinearSegmentedColormap.from_list('tmp',[(1, 1, 1), colormaps['rainbow'](genome_position)], N=512)
    return cm(prob/100)

def get_color_dict(clan_annotation:pd.Series,used_cm=['tab10','Set2','Accent','Set3','Pastel2','Dark2']):
    ''' clan colors '''
    uni_annotation=clan_annotation.unique()
    lengths=[colormaps[i].N for i in used_cm]
    assert len(uni_annotation)<=sum(lengths),(f'no enough colors:'
         f'{len(uni_annotation)} vs {sum(lengths)}')
    out_dict={}
    cpkt=[0]+list(accumulate(lengths))
    cm_pointer=0
    for i,j in enumerate(uni_annotation):
        if i>=cpkt[cm_pointer+1]:
            cm_pointer+=1
        color=colormaps[used_cm[cm_pointer]](i-cpkt[cm_pointer])
        out_dict[j]=color
    return out_dict

# %%
# from matplotlib.backends.backend_pdf import PdfPages
# if 0:
#     with PdfPages('poc2.pdf') as pdf:
#         for genome_res in search_result[:2]:
#             genome_res:Tuple[Path,List[Tuple[Path,List[str]]]]
#             genome,o=parse_genome_res(genome_res)
#             fig,ax=plt.subplots(1,1,sharex=True,figsize=(30,10))
#             features=[]
#             len_genome=len(genome)
#             for (transannot,prob,proe),hit in o:
#                 hit:Hit
                
#                 genomeb,genomee=proindice_to_genindice(genome,prob+hit.begin,prob+hit.end,transannot)
#                 strand=1 if transannot.endswith('s') else -1
#                 rele_pos=(genomeb+genomee)/2/len_genome
#                 features.append(GraphicFeature(start=genomeb, end=genomee, strand=strand,
#                                 label=hit.domain_annotation,color=get_color(rele_pos,hit.prob)))
                
#             record = GraphicRecord(sequence_length=len_genome, features=features)
#             record.plot(ax=ax,figure_width=20)
#             fig.suptitle(genome.id)
#             pdf.savefig(fig)
#             plt.close(fig)

# %% [markdown]
# involve clans

# %%
import numpy as np
from functools import partial

def df_to_dict(df:pd.DataFrame,k:str,v:str):
    return df.set_index(k)[v].T.to_dict()
clans=pd.read_csv('Pfam-A.clans.tsv',delimiter='\t',header=None)
clans.columns=['domain','clan','clan_name','domain_name','domain_annotation']
clan_dict=df_to_dict(clans,'domain','clan')
clan_name_dict=df_to_dict(clans,'domain','clan_name')

def query_clan(domain_accession:str,domain_annotation):
    clan_accession=clan_dict.get(domain_accession,np.nan)
    if clan_accession!=clan_accession:
        clan_accession=domain_accession
    clan_annotation=clan_name_dict.get(domain_accession,np.nan)
    if clan_annotation!=clan_annotation:
        clan_annotation=domain_annotation
    return clan_accession,clan_annotation

# %%
from matplotlib.backends.backend_pdf import PdfPages
# genome,o=parse_genome_res(genome_res)
def parse_genome_res(genome_res:Tuple[Path,List[Tuple[Path,List[str]]]]):
    stem=genome_res[0].stem
    stems=stem.replace(':segs','').split('|')
    genome_fasta_path=genome_res[0].with_stem(stem.replace('segs','genome'))
    genome:SeqRecord=SeqIO.read(genome_fasta_path,'fasta')
    o:List[Tuple[SegMeta,Hit]]=[]
    
    for seg_res in genome_res[1]:
        if len(seg_res[1])>0:
            _,transannot,prob,proe=seg_res[0].stem.split('#')
            prob,proe=int(prob),int(proe)
            segmeta=SegMeta(transannot=transannot,seg_b=prob,seg_e=proe)
            for h in seg_res[1]:
                hit=parse_splited_hit_line(h)
                o.append((segmeta,hit))   
    return genome,o
def genome_res_to_hits_df(genome:SeqRecord,parse_o:List[Tuple[SegMeta,Hit]])->pd.DataFrame:
    hits_df=pd.concat([pd.DataFrame([i[1] for i in parse_o]),pd.DataFrame([i[0] for i in parse_o])],axis=1) 
    hits_df['gen_b'],hits_df['gen_e']=np.vectorize(partial(
        proindice_to_genindice,genome=genome))(
        prob=hits_df['begin']+hits_df['seg_b'],
        proe=hits_df['end']+hits_df['seg_b'],
        transannot=hits_df['transannot'])

    hits_df['gen_hmm_b'],hits_df['gen_hmm_e']=np.vectorize(partial(
        proindice_to_genindice,genome=genome))(
        prob=hits_df['begin']-hits_df['hmmbegin']+1+hits_df['seg_b'],
        proe=hits_df['end']+hits_df['hmmlength']-hits_df['hmmend']+hits_df['seg_b'],
        transannot=hits_df['transannot'])
    hits_df['clan_accession'],hits_df['clan_annotation']=np.vectorize(query_clan)(
        hits_df['domain_accession'],hits_df['domain_annotation'])
    return hits_df


def inspect_genome_res(genome_res:Tuple[Path,List[Tuple[Path,List[str]]]]):
    genome,o=parse_genome_res(genome_res)
    hits_df=genome_res_to_hits_df(genome,o)
    genome_id=genome.id
    count=0
    len_genome=len(genome)
    color_dict=get_color_dict(hits_df['clan_annotation'])
    with PdfPages(f'{genome_id}.pdf') as pdf:
        while count<4:
            fig,ax=plt.subplots(1,1,sharex=True,figsize=(30,12))
            features=[]
            titles=[f'{genome_id}-origin\n50prob-domaincolor-hitindice',f'{genome_id}-filterdomain\n90prob-domaincolor-hitindice',
                    f'{genome_id}-color-as-clan\n90prob-clancolor-hitindice',f'{genome_id}-cover-whole-hmm\n90prob-clancolor-hmmindice']
            for _,s in hits_df.iterrows():
                strand=1 if s['transannot'].endswith('s') else -1
                if count==0:
                    if s['prob']>=0:
                        genomeb,genomee=s['gen_b'],s['gen_e']
                        rele_pos=(genomeb+genomee)/2/len_genome
                        features.append(GraphicFeature(start=genomeb, end=genomee, strand=strand,
                                        label=s['domain_annotation'],color=get_color(rele_pos,s['prob'])))
                elif count==1:
                    if s['prob']>=90:
                        genomeb,genomee=s['gen_b'],s['gen_e']
                        rele_pos=(genomeb+genomee)/2/len_genome
                        features.append(GraphicFeature(start=genomeb, end=genomee, strand=strand,
                                        label=s['domain_annotation'],color=get_color(rele_pos,s['prob'])))
                elif count==2:
                    if s['prob']>=90:
                        genomeb,genomee=s['gen_b'],s['gen_e']
                        features.append(GraphicFeature(start=genomeb, end=genomee, strand=strand,
                                        label=s['clan_annotation'],color=color_dict[s['clan_annotation']]))
                elif count==3:
                    if s['prob']>=90:
                        genomeb,genomee=s['gen_hmm_b'],s['gen_hmm_e']
                        features.append(GraphicFeature(start=genomeb, end=genomee, strand=strand,
                                        label=s['clan_annotation'],color=color_dict[s['clan_annotation']]))
                    
            record = GraphicRecord(sequence_length=len_genome, features=features)
            record.plot(ax=ax,figure_width=20)
            # fig.show()
            fig.suptitle(titles[count],fontsize=20)
            pdf.savefig(fig)
            plt.close(fig)
            count=count+1

# %%
# from matplotlib import rcParams
# type(rcParams['axes.prop_cycle'])

# %%
def all_in_one_parse(genome_res:Tuple[Path,List[Tuple[Path,List[str]]]]):
    genome,parse_o=parse_genome_res(genome_res)
    hits_df=genome_res_to_hits_df(genome,parse_o)
    return genome,parse_o,hits_df

genome_res = search_result[1]
genome,parse_o,hits_df=all_in_one_parse(genome_res)
# genome,o=parse_genome_res(genome_res)
# hits_df=genome_res_to_hits_df(genome,o)

# inspect_genome_res(genome_res)

# %%
search_result_dict = {i[0].stem.strip(':segs'):i for i in search_result}

# %%
zika_res=search_result_dict['ZIKV||AY632535']
zika_os=all_in_one_parse(zika_res)

# %%
for i in ['ZIKV||AY632535','EBOV||AF086833',
    'MeV||AB016162','SARS-CoV-2||MN908947',
    'RPbV||KC815311','TBEV-FE||X07755',
    'WPSSPV||MG600057','KNDV||MW093492']:
    try:
        genome_res=search_result_dict[i]
        inspect_genome_res(genome_res)
    except:
        print(i)
# Out:
# /home/hugheslab1/zfdeng/.local/lib/python3.12/site-packages/numpy/lib/function_base.py:2455: RuntimeWarning: invalid value encountered in query_clan (vectorized)
#   outputs = ufunc(*inputs)
# /home/hugheslab1/zfdeng/.local/lib/python3.12/site-packages/numpy/lib/function_base.py:2455: RuntimeWarning: invalid value encountered in query_clan (vectorized)
#   outputs = ufunc(*inputs)
# /home/hugheslab1/zfdeng/.local/lib/python3.12/site-packages/numpy/lib/function_base.py:2455: RuntimeWarning: invalid value encountered in query_clan (vectorized)
#   outputs = ufunc(*inputs)
# /home/hugheslab1/zfdeng/.local/lib/python3.12/site-packages/numpy/lib/function_base.py:2455: RuntimeWarning: invalid value encountered in query_clan (vectorized)
#   outputs = ufunc(*inputs)
# /home/hugheslab1/zfdeng/.local/lib/python3.12/site-packages/numpy/lib/function_base.py:2455: RuntimeWarning: invalid value encountered in query_clan (vectorized)
#   outputs = ufunc(*inputs)
# WPSSPV||MG60005
# /home/hugheslab1/zfdeng/.local/lib/python3.12/site-packages/numpy/lib/function_base.py:2455: RuntimeWarning: invalid value encountered in query_clan (vectorized)
#   outputs = ufunc(*inputs)

# %%
genome_res=search_result_dict['OSV-1||MF324848']
inspect_genome_res(genome_res)

# %% [markdown]
# 'ZIKV||AY632535'
#     hint: too brutal to use hmm indice directly
#     cause pseudo overlap in Orbi_VP1,P-loop_NTPase
#     some families are actually multidomain (e.g. RdRP3); partial hit is ONLY partial hit.
#
# 'EBOV||AF086833'
#     pseudo double hit of Filo_glycop
#     G-7-MTase & NADP_Rossmann(e.g Fstj): mighe be the same thing samething
#
#
# 'MeV||AB016162'
#     pseudo double hit of Paramyxovirin_C
#
# 'SARS-CoV-2||MN908947'
#     so many hits, disaster
#     to be analysed again after hhm/hhm-align and redefine clan
#
#
# 'RPbV||KC815311':
#     homology of zika, classic false-negative with PF00998 instead of zika's rdrp (PF00792) hit
#     one more hit found (1st on the left)
#
# 'TBEV-FE||X07755'
#     homology of zika, out-of-distribution
#     very tidy, perfect
#
# 'WPSSPV||MG600057'
#     homology of measles, with long segs of false-negative (no hit in Interproscan)
#     no more domain hit
#
# 'KNDV||MW093492
#     homology of ebola, with long segs of false-negative (no hit in Interproscan)
#     some DUFs and ZFs hit in that missing area, with low(50-90) prob
#
# 'OSV-1||MF324848'
#     homology of covid, random chosen.

# %% [markdown]
# Legend for each cases:
# 1. Standard refs for Covid/Zika/Ebola/Measles
#     ZIKV||AY632535
#
#     EBOV||AF086833
#
#     MeV||AB016162
#
#     SARS-CoV-2||MN908947
#
# 2. Representative homologs:
#     RPbV||KC815311:
#         homology of zika, classic false-negative with PF00998 instead of zika's rdrp (PF00792) hit
#
#     TBEV-FE||X07755:
#         homology of zika, out-of-distribution orphan
#
#     WPSSPV||MG600057
#         homology of measles, with long segs of false-negative (no hit in Interproscan)
#
#     KNDV||MW093492
#         homology of ebola, with long segs of false-negative (no hit in Interproscan)

# %%
# from glob import glob
for i in Path('.').iterdir():
    if i.suffix=='.pdf':
        new_stem=i.stem.replace('|','#')
        i.rename(i.with_stem(new_stem))

# %% [markdown]
# Progress:
# hh-blits returns every possible hits as we expected
#
# hh-blits could hit domains ignored by Interproscan (RPbV||KC815311,OSV-1||MF324848)
#
# hh-blits could fix false loops (multi-hit. e.g MeV||AB016162)
#
# Issues:
# hh-blits is slower than interproscan (avg: 20core * 20s; interproscan: 4core * 15s)
#     reason: interproscan could predict ORFs,
#             while translation of multiple segs (most of them are useless) will be analyzed tandemly in hh-blits
#
# False ORF could yield false hit (small fragments) with high probability
#
# Pfam clan is very rough. rerun with hhblits is definitely needed.
#
# Too brutal to use hmm indice directly, which might cause pseudo overlap
#
# hitting of domains ignored by Interproscan is still not perfect (WPSSPV||MG600057, KNDV||MW093492)
#
# SARS-CoV-2||MN908947: too many hits to be disaster

# %%
zika_os[2]
# Out:
#     domain_accession domain_annotation   prob          eval          pval  \
# 0            PF19215       CoV_NSP15_C  100.0  3.700000e-36  7.200000e-40
# 1            PF17977        zf-RING_13   99.7  1.800000e-22  3.300000e-26
# 2            PF00978            RdRP_2   99.6  1.900000e-21  4.400000e-25
# 3            PF00998            RdRP_3   99.5  6.300000e-19  1.500000e-22
# 4            PF17873            Rep_1B   99.4  4.700000e-18  8.600000e-22
# ..               ...               ...    ...           ...           ...
# 97           PF12046              CCB1   74.1  1.300000e-01  2.800000e-05
# 98           PF02340         PRRSV_Env   77.3  9.200000e-02  2.000000e-05
# 99           PF00951         Arteri_Gl  100.0  1.800000e-65  3.500000e-69
# 100          PF01481     Arteri_nucleo  100.0  5.800000e-46  1.100000e-49
# 101          PF16623     WW_FCH_linker   67.3  2.200000e-01  5.100000e-05
#
#      score   ss  begin   end  hmmbegin  ...  hmmlength  transannot seg_b  \
# 0    303.1  0.0   1174  1294         1  ...        155          0s  2069
# 1    174.0  0.0    636   696         1  ...         68          0s  2069
# 2    218.1  0.0    331   571       148  ...        440          0s  2069
# 3    197.8  0.0    331   574       135  ...        479          0s  2069
# 4    140.5  0.0    709   760         1  ...         53          0s  2069
# ..     ...  ...    ...   ...       ...  ...        ...         ...   ...
# 97    35.7  0.0     86   132        62  ...        171          2s   792
# 98    40.3  0.0    211   286       139  ...        233          2s  3492
# 99   432.9  0.0     77   244         6  ...        173          2s  4012
# 100  271.1  0.0     19   123        10  ...        115          2s  4423
# 101   27.5  0.0     81    89        66  ...         93          2a  1659
#
#      seg_e  gen_b  gen_e  gen_hmm_b  gen_hmm_e  clan_accession clan_annotation
# 0     3485   9729  10089       9729      10092          CL0695           EndoU
# 1     3485   8115   8295       8115       8304          CL0229            RING
# 2     3485   7200   7920       6759       8109          CL0027            RdRP
# 3     3485   7200   7929       6798       8238          CL0027            RdRP
# 4     3485   8334   8487       8334       8490          CL0105          Hybrid
# ..     ...    ...    ...        ...        ...             ...             ...
# 97     977   2636   2774       2453       2948         PF12046            CCB1
# 98    3792  11111  11336      10697      11384         PF02340       PRRSV_Env
# 99    4257  12269  12770      12254      12773         PF00951       Arteri_Gl
# 100   4549  13328  13640      13301      13643         PF01481   Arteri_nucleo
# 101   1762   8520   8544       8463       8739         PF16623   WW_FCH_linker
#
# [102 rows x 21 columns]

# %%
[i[0].stem for i in search_result]
# Out:
# ['AAbV||GBBW01007738:segs',
#  'OSV-1||MF324848:segs',
#  'EAV||X53459:segs',
#  'APRAV||KP026921:segs',
#  'SHFV||AF180391:segs',
#  'SHEV||KM677927:segs',
#  'FSVV||KR862307:segs',
#  'ZMbV-1||KT166441:segs',
#  'KRCV-2||KC787658:segs',
#  'DeBMAV||KP126831:segs',
#  'KRTGV-1||JX473849:segs',
#  'PBJV||KR139839:segs',
#  'KKCBV||KT447550:segs',
#  'MYBV-1||KM110938:segs',
#  'KRCV-1||KC787630:segs',
#  'PRRSV-2||U87392:segs',
#  'RtMrufAV||KP280006:segs',
#  'RtClonAV||KU302440:segs',
#  'RtEiAV||KY369968:segs',
#  'PRRSV-1||M96262:segs',
#  'RtMcAV||KY369967:segs',
#  'LDV||U15146:segs',
#  'RtClanAV||KY369969:segs',
#  'WPDV||JN116253:segs',
#  'TSHSV-NX1||MH447987:segs',
#  'CBHPTAV||MG600025:segs',
#  'GGGSAV||MG600023:segs',
#  'HOFAV||MG600022:segs',
#  'MLeV||GECV01031551:segs',
#  'BtCoV-AMA-L-F||MT663548:segs',
#  'BtCoV CDPHE15||KF430219:segs',
#  'HipPBCoV-CHB25||MN611525:segs',
#  'ACoV-WA3607||MK472070:segs',
#  'BtCoV HKU10||JQ989270:segs',
#  'BtRf-AlphaCoV||KJ473807:segs',
#  'HCoV_229E||AF304460:segs',
#  'HCoV_229E||JX503061:segs',
#  'LRNV||KF294380:segs',
#  'MCoV||HM245925:segs',
#  'Mi-BatCoV_1A||EU420138:segs',
#  'Mi-BatCoV_HKU8||EU420139:segs',
#  'BtMr-AlphaCoV||KJ473806:segs',
#  'TyBCoV-HKU33||MK720944:segs',
#  'ACoV-WA2028||MK472068:segs',
#  'BtNv-AlphaCoV||KJ473809:segs',
#  'PK-BatCoV||MH938449:segs',
#  'ACoV-WA1087||MK472067:segs',
#  'PEDV||AF353511:segs',
#  'Sc-BatCoV_512||DQ648858:segs',
#  'Rh-BatCoV_HKU2||EF203064:segs',
#  'HCoV_NL63||AY567487:segs',
#  'BtKYNL63||KY073745:segs',
#  'Sa-CoV_T14||KY370053:segs',
#  'Sm-CoV_X74||KY967715:segs',
#  'TGEV||AJ271965:segs',
#  'HCoV_OC43||AY585228:segs',
#  'ChRCoV_HKU24||KM349742:segs',
#  'HCoV_HKU1||AY597011:segs',
#  'MHV||AY700211:segs',
#  'MrufCoV_2JL14||KY370046:segs',
#  'Bat_Hp-BetaCoV||KF636752:segs',
#  'EriCoV||KC545383:segs',
#  'MERS-CoV||JX869059:segs',
#  'Pi-BatCoV_HKU5||EF065509:segs',
#  'Ty-BatCoV-HKU4||EF065505:segs',
#  'Ei-BatCoV_C704||MG693168:segs',
#  'Ro-BatCoV_GCCDC1||KU762338:segs',
#  'Ro-BatCoV_HKU9||EF065513:segs',
#  'SARS-CoV||AY274119:segs',
#  'SARSr-CoV||KY352407:segs',
#  'SARS-CoV-2||MN908947:segs',
#  'SARS-CoV||AY613950:segs',
#  'WiCoV_HKU20||JQ065048:segs',
#  'BulCV_HKU11||FJ376619:segs',
#  'CMCoV_HKU21||JQ065049:segs',
#  'PoCoV_HKU15||JQ065043:segs',
#  'MunCV_HKU13||FJ376622:segs',
#  'WECoV_HKU16||JQ065044:segs',
#  'NHCoV_HKU19||JQ065047:segs',
#  'BcanCoV_CB17||MK359255:segs',
#  'BWCoV||EU111742:segs',
#  'BdCoV_HKU22||KF793824:segs',
#  'IBV||M95169:segs',
#  'ACoV_9203||KR902510:segs',
#  'DuCoV_2714||KM454473:segs',
#  'PsNV||MK611985:segs',
#  'BlNV||MK956105:segs',
#  'TurrNV||KX883629:segs',
#  'CASV||KJ125489:segs',
#  'NseV||JQ957874:segs',
#  'HanaV||JQ957872:segs',
#  'KADV||KT966495:segs',
#  'KSaV||KC807171:segs',
#  'DKNV||AB753015:segs',
#  'MenoV||JQ957873:segs',
#  'NDV||DQ458789:segs',
#  'DiankeV||KY056254:segs',
#  'OFAV||KT966491:segs',
#  'YiV-HB-MLV||KY369959:segs',
#  'InsMV-1||MN714662:segs',
#  'ACMV||MN961271:segs',
#  'FOaMV-1||MN714663:segs',
#  'PSCNV||MH933735:segs',
#  'NGSAV||MG600024:segs',
#  'WJHAV||MG600020:segs',
#  'CharNV||KX883628:segs',
#  'DecNV||KX883636:segs',
#  'PagRV||KX883627:segs',
#  'MrGV||MT907511:segs',
#  'GAV||AF227196:segs',
#  'YHV||EU487200:segs',
#  'YHV-8||KX947267:segs',
#  'WBV||DQ898157:segs',
#  'FHMNV||GU002364:segs',
#  'CSV||KJ681496:segs',
#  'BoNV||KM589359:segs',
#  'HpoToV_33749||MG600028:segs',
#  'SerTV-25||MN161572:segs',
#  'INTOV||KX883638:segs',
#  'VCSTV-A||MT997160:segs',
#  'GRBSToV||MG600030:segs',
#  'BPNV||KJ541759:segs',
#  'MVNV||MF351889:segs',
#  'MoVNV||MK182569:segs',
#  'BRV||MF685025:segs',
#  'ShNV||KX184715:segs',
#  'SECTOV||KX883637:segs',
#  'SerTV-K48||MN161566:segs',
#  'SerTV-C18||MN161561:segs',
#  'VCSTV-B||MT997159:segs',
#  'BaToV-Hrufipes2018||MW561977:segs',
#  'BRV||AY427798:segs',
#  'EToV|0|DQ310701:segs',
#  'EToV|1|X52506:segs',
#  'EToV|2|X52505:segs',
#  'PoTV||JQ860350:segs',
#  'BoHV||KP641127:segs',
#  'GHV||KC551800:segs',
#  'NPHV||KP325401:segs',
#  'RHV-J||KC411777:segs',
#  'HCV1a||AF009606:segs',
#  'HCV1a||M62321:segs',
#  'HCV1b||D90208:segs',
#  'HCV2a||D00944:segs',
#  'HCV2b||D10988:segs',
#  'HCV3a||D17763:segs',
#  'HCV3k||D63821:segs',
#  'HCV4a||GU814265:segs',
#  'HCV5a||Y13184:segs',
#  'HCV6a||Y12083:segs',
#  'HCV6g||D63822:segs',
#  'HCV7a||EF108306:segs',
#  'BHV-K||KC796074:segs',
#  'RHV-F||KC411784:segs',
#  'NRHV2||KJ950939:segs',
#  'BHV-M||KC796078:segs',
#  'RHV-E||KC815310:segs',
#  'GBV-B||U22304:segs',
#  'NRHV1||KJ950938:segs',
#  'NRHV1||KX905133:segs',
#  'RHV-I||KC411806:segs',
#  'BHV-L||KC796077:segs',
#  'APOIV||AF160193:segs',
#  'AROAV||AY632536:segs',
#  'AROAV||AF013362:segs',
#  'BSQV||AF013366:segs',
#  'IGUV||AF013375:segs',
#  'NJLV||AF013390:segs',
#  'BAGV||AY632545:segs',
#  'BANV||DQ859056:segs',
#  'BOUV||DQ859057:segs',
#  'RBV||AF144692:segs',
#  'BBV||AF013365:segs',
#  'CPCV||KF917536:segs',
#  'CIV||AF013368:segs',
#  'CRV||AF013370:segs',
#  'DBV||AF013371:segs',
#  'DENV-2||U87411:segs',
#  'DENV-1||U88536:segs',
#  'DENV-3||M93130:segs',
#  'DENV-4||AF326573:segs',
#  'EHV||DQ859060:segs',
#  'TBEV-Eur||U27495:segs',
#  'TBEV-FE||X07755:segs',
#  'TBEV-Sib||L40361:segs',
#  'ENTV||DQ837641:segs',
#  'SOKV||AF013405:segs',
#  'YFV||X03700:segs',
#  'GGYV||DQ235145:segs',
#  'ILHV||AY632539:segs',
#  'ROCV||AF013397:segs',
#  'ITV||AF013377:segs',
#  'JEV||M18370:segs',
#  'JUGV||DQ859066:segs',
#  'JUTV||KJ469371:segs',
#  'KADV||DQ235146:segs',
#  'KEDV||AY632540:segs',
#  'KOKV||AY632541:segs',
#  'STRV||AF013407:segs',
#  'KOUV||AF013384:segs',
#  'KFDV||AY323490:segs',
#  'AHFV||AF331718:segs',
#  'LGTV||AF253419:segs',
#  'SLEV||DQ525916:segs',
#  'LIV||Y07863:segs',
#  'LIV-Brit||D12937:segs',
#  'LIV-Ir||X86784:segs',
#  'LIV-Spain||DQ235152:segs',
#  'TSEV||DQ235151:segs',
#  'GGEV||DQ235153:segs',
#  'MEAV||DQ235144:segs',
#  'MODV||AJ242984:segs',
#  'MMLV||AJ299445:segs',
#  'MVEV||AF161266:segs',
#  'ALFV||AF013360:segs',
#  'WNV||M12294:segs',
#  'KUNV||D00246:segs',
#  'NTAV||JX236040:segs',
#  'OHFV||AY193805:segs',
#  'SPV||AF013402:segs',
#  'PPBV||AF013394:segs',
#  'BCV||AF013369:segs',
#  'POWV||L06436:segs',
#  'DTV||AF311056:segs',
#  'RFV||DQ235149:segs',
#  'SABV||DQ859062:segs',
#  'POTV||DQ859067:segs',
#  'SREV||DQ235150:segs',
#  'SEPV||DQ837642:segs',
#  'TMUV||JF895923:segs',
#  'TYUV||KF815939:segs',
#  'UGSV||DQ859065:segs',
#  'USUV||AY453411:segs',
#  'SVV||AF013401:segs',
#  'WESSV||EU707555:segs',
#  'YAOV||AF013413:segs',
#  'YOKV||AB114858:segs',
#  'ZIKV||AY632535:segs',
#  'ZIKV||KY766069:segs',
#  'ZIKV||KJ776791:segs',
#  'ZIKV||KX377337:segs',
#  'EPgV||KC410872:segs',
#  'BPgV-F||KC796080:segs',
#  'HHPgV||KT439329:segs',
#  'TDAV||KC145265:segs',
#  'HPgV||U44402:segs',
#  'HPgV||U63715:segs',
#  'HPgV||AB003289:segs',
#  'HPgV||U45966:segs',
#  'HPgV||AY196904:segs',
#  'HPgV||D87713:segs',
#  'HPgV||AB021287:segs',
#  'HPgV||AY949771:segs',
#  'HPgV||AB003292:segs',
#  'SPgV-ch||AF070476:segs',
#  'RPbV||KC815311:segs',
#  'GBV-A||U22303:segs',
#  'GBV-A||U94421:segs',
#  'GBV-D||GU566734:segs',
#  'GBV-D||GU566735:segs',
#  'BPgV-G||KC796076:segs',
#  'BPgV-I||KC796088:segs',
#  'PPgV||KU351669:segs',
#  'PAPeV||AY781152:segs',
#  'PPeV||EF100713:segs',
#  'AydinPeV||JX428945:segs',
#  'BVDV1||M96751:segs',
#  'BVDV1||M31182:segs',
#  'HoBiPeV||FJ040215:segs',
#  'GPeV||AF144617:segs',
#  'LindaV||KY436034:segs',
#  'PhoPeV||MK910227:segs',
#  'TSV||MZ664274:segs',
#  'ovIT PeV||MK618726:segs',
#  'BDV||AF037405:segs',
#  'DYPV||MK636874:segs',
#  'RtNn-PeV||KY370101:segs',
#  'RtAp-PeV||KY370100:segs',
#  'RPeV||KJ950914:segs',
#  'BtSk-PeV||MH282908:segs',
#  'APPeV||KR011347:segs',
#  'CSFV||X87939:segs',
#  'BVDV2||FJ527854:segs',
#  'BVDV2||U18059:segs',
#  'LLOV||JF828358:segs',
#  'MLAV||KX371887:segs',
#  'OBLV||MN510773:segs',
#  'BOMV||MF319185:segs',
#  'BDBV||FJ217161:segs',
#  'RESTV||AF522874:segs',
#  'SUDV||AY729654:segs',
#  'TAFV||FJ217162:segs',
#  'EBOV||AF086833:segs',
#  'MARV||DQ217792:segs',
#  'RAVV||DQ447649:segs',
#  'XILV||MG599980:segs',
#  'TAPV||BR001752:segs',
#  'KNDV||MW093492:segs',
#  'FIWIV||MN510772:segs',
#  'HUJV||MG599981:segs',
#  'APMV8||FJ215863:segs',
#  'APMV10||HM147142:segs',
#  'APMV11||JQ886184:segs',
#  'APMV6||EF569970:segs',
#  'APMV14||KX258200:segs',
#  'APMV20||MF033136:segs',
#  'APMV5||GU206351:segs',
#  'APMV15||KX932454:segs',
#  'APMV22||MK677430:segs',
#  'APMV7||FJ231524:segs',
#  'APMV2||EU338414:segs',
#  'APVA||KY452442:segs',
#  'APMV12||KC333050:segs',
#  'APMV13||LC041132:segs',
#  'APMV1||AY562991:segs',
#  'APVB||KY452443:segs',
#  'APMV21||MF594598:segs',
#  'APMV9||EU910942:segs',
#  'APVC||KY452444:segs',
#  'APMV16||KY511044:segs',
#  'APMV4||EU877976:segs',
#  'APMV3||EU782025:segs',
#  'WTLPV||MG600058:segs',
#  'PSPV||MH900516:segs',
#  'ASPV||EU156171:segs',
#  'FDLV||AY141760:segs',
#  'CedV||JQ001776:segs',
#  'GhV||HQ660129:segs',
#  'HeV||AF017149:segs',
#  'MojV||KF278639:segs',
#  'NiV||AF212302:segs',
#  'MisPV||KC154054:segs',
#  'RoPV||KY370098:segs',
#  'BeiV||DQ100461:segs',
#  'BatPV1||MG203877:segs',
#  'BeV||MN561699:segs',
#  'FPaV||LC431581:segs',
#  'MMLV1||MG573140:segs',
#  'MMLV2||MG573141:segs',
#  'BatPV2||MG203878:segs',
#  'ShaV||MG230624:segs',
#  'BatPV3||KJ641657:segs',
#  'PMPV1||MG516455:segs',
#  'JV||AY900001:segs',
#  'RulV||MW579602:segs',
#  'TaiV||JN689227:segs',
#  'CDV||AF014953:segs',
#  'PPRV||AJ849636:segs',
#  'CeMV||AJ608288:segs',
#  'FeMV||JQ411014:segs',
#  'MeV||AB016162:segs',
#  'RPV||X98291:segs',
#  'PDV||KC802221:segs',
#  'MossV||AY286409:segs',
#  'BaV1||MF943130:segs',
#  'NarV||FJ362497:segs',
#  'TupV||AF079780:segs',
#  'BPIV3||AF178654:segs',
#  'CPIV3||KT215610:segs',
#  'HPIV1||AF457102:segs',
#  'SeV||AB195968:segs',
#  'HPIV3||EU326526:segs',
#  'GSqV||LS992584:segs',
#  'PPIV1||JX857409:segs',
#  'SalV||JQ697837:segs',
#  'AlsV||MH972568:segs',
#  'HPIV4a||AB543336:segs',
#  'HPIV4b||AB543337:segs',
#  'HPIV2||X57559:segs',
#  'PIV5||AF052755:segs',
#  'MapV||EF095490:segs',
#  'MuV||AB040874:segs',
#  'SV41||X64275:segs',
#  'LPMV||BK005918:segs',
#  'AchPV2||JX051320:segs',
#  'AchPV1||JX051319:segs',
#  'ThkPV2||GU128081:segs',
#  'ThkPV1||GU128080:segs',
#  'HerV||KU672593:segs',
#  'ThkPV3||GU128082:segs',
#  'MenPV||JX112711:segs',
#  'SOSV||KF774436:segs',
#  'TevPV||KP271124:segs',
#  'TioPV||AF298895:segs',
#  'WTSPV||MG600059:segs',
#  'WHPV||MG600062:segs',
#  'WPSSPV||MG600057:segs']

# %% [markdown]
# ## note for OSV-1||MF324848-origin
# ### case1. the clan nearby should include this two entry.
# 1. Orbi_VP1:
#     https://www.ebi.ac.uk/interpro/entry/pfam/PF05788/
#     Also RdRp
#
# 2. IFR3_antag:
#     https://www.ebi.ac.uk/interpro/entry/pfam/PF14754/
#     Also proteinase, and hit prob=100% here.
#
# ### case2 accessory domains of nearby function domain
# 1. Hybird (Rep_1B)
#     https://www.ebi.ac.uk/interpro/entry/pfam/PF17873/
#     "a regulatory domain found in replicase polyprotein 1ab found in Arterivirus"
#
#     hybrid:
#     This superfamily contains proteins with a hybrid motif embedded in structurally diverse proteins.
#     PMID: 8081735
#
# 2. DUF3388
#     https://www.ebi.ac.uk/interpro/entry/pfam/PF11868/
#     'functionally uncharacterised. This protein is found in bacteria'
#     'associated with Pfam:PF01842: ACT domain'
#
# 3. RING (zf-RING_13)
#     https://www.ebi.ac.uk/interpro/entry/pfam/PF17977/
#     RING/Ubox like zinc-binding domain
#
# ### case3 valid multiple hits
# 1. Arteri_Gl
#     https://www.ebi.ac.uk/interpro/entry/pfam/PF00951/
#     Gl envelope protein encoded by Arteriviruses
#
# ### case4 multiple hits should be integrated
# 1. Peptidase_S46
#     https://www.ebi.ac.uk/interpro/entry/pfam/PF10459/
#     member of Peptidase_PA

# %%
hits_df['domain_annotation'].value_counts()[hits_df['domain_annotation'].value_counts()>1]
# Out:
# domain_annotation
# Arteri_Gl        2
# Peptidase_S46    2
# Name: count, dtype: int64

# %%
hits_df[hits_df['domain_annotation']=='Peptidase_S46'].T
# Out:
#                               89             94
# domain_accession         PF10459        PF10459
# domain_annotation  Peptidase_S46  Peptidase_S46
# prob                        95.2           74.0
# eval                     0.00011           0.12
# pval                         0.0       0.000028
# score                       84.0           57.3
# ss                           0.0            0.0
# begin                       1393           1487
# end                         1418           1513
# hmmbegin                      43            640
# hmmend                        66            666
# hmmlength                    709            709
# transannot                    1s             1s
# seg_b                         23             23
# seg_e                       2091           2091
# gen_b                       4249           4531
# gen_e                       4324           4609
# gen_hmm_b                   4123           2614
# gen_hmm_e                   6253           4738
# clan_accession            CL0124         CL0124
# clan_annotation     Peptidase_PA   Peptidase_PA

# %%
hits_df[hits_df['clan_annotation']=='Arteri_Gl'].T
# Out:
#                           96         99
# domain_accession     PF00951    PF00951
# domain_annotation  Arteri_Gl  Arteri_Gl
# prob                   100.0      100.0
# eval                     0.0        0.0
# pval                     0.0        0.0
# score                  344.7      432.9
# ss                       0.0        0.0
# begin                     17         77
# end                      182        244
# hmmbegin                  18          6
# hmmend                   172        172
# hmmlength                173        173
# transannot                1s         2s
# seg_b                   4247       4012
# seg_e                   4430       4257
# gen_b                  12793      12269
# gen_e                  13288      12770
# gen_hmm_b              12742      12254
# gen_hmm_e              13291      12773
# clan_accession       PF00951    PF00951
# clan_annotation    Arteri_Gl  Arteri_Gl
